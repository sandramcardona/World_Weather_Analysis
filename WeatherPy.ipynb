# %%
#create Latitude and Longitude Combinations - 6.1.4
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#create a set of random latitude and longitude combinations.
# we'll create a similar code snippet that will generate longitudes. 
# To ensure enough latitudes and longitudes, we'll start with 1,500. 
# In addition, we'll pack the latitudes (lats) and longitudes (lngs) 
# as pairs by zipping them (lat_lngs) with the zip() function.

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#let's unpack our lat_lngs zip object into a list. This way, we 
# only need to create a set of random latitudes and longitudes once. 
# In a new cell in the WeatherPy.ipynb file, add the following code 
# and run the cell.

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# tual id
# busselton au
# port elizabeth za
# vestmannaeyjar is
# ushuaia ar
# vao nc
# upernavik gl
# college us
# kerman ir
# isangel vu
# mataura pf
# punta arenas cl
# faanui pf
# georgetown sh
# lolua tv
# bambous virieux mu
# novikovo ru
# cabo san lucas mx
# concordia ar
# kapaa us
# jiroft ir
# hobart au
# ilulissat gl
# kapaa us
# belushya guba ru
# punta arenas cl
# pervomayskiy ru
# sitka us
# port alfred za
# mar del plata ar
# saldanha za
# mason city us
# cape town za
# tambo grande pe
# kapaa us
# dikson ru
# punta arenas cl
# mys shmidta ru
# alanya tr
# tocopilla cl
# amderma ru
# tyulyachi ru
# yellowknife ca
# te anau nz
# ushuaia ar
# illoqqortoormiut gl
# carnarvon au
# cherskiy ru
# kapaa us
# bargal so
# thompson ca
# ancud cl
# ancud cl
# new norfolk au
# pisco pe
# ushuaia ar
# khatanga ru
# caluquembe ao
# strezhevoy ru
# huaraz pe
# harlingen nl
# nikolskoye ru
# georgetown sh
# castro cl
# cockburn town tc
# georgetown sh
# nanortalik gl
# usinsk ru
# ...

# %%
# Create a list for holding the cities. 6.1.5
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630

# %%
# - 6.2.6 - Import Dependencies, and Initialize an Empty List and Counters

#Import the requests library - 6.2.3
import requests

#Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=00e7cb7aed8565887497994e821448e0

# %%
#Import the datetime module from the dateime library
from datetime import datetime

#Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging.
print("Beginning data Retrieval      ")
print("------------------------------")

#Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning data Retrieval
# ------------------------------

# %%
#Loop Through the List of Cities and Build the City URL
# Next, we need to iterate through our list of cities and begin building
# the URL for each city, while grouping our records in sets of 50. 
# To do this, use for i in range(len(cities)) and the index to tell us
# when we get to 50. We can also retrieve the city from the cities list
# and add it to the city_url by using indexing, as shown in the following
# code:

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
# - 6.2.6 - Import Dependencies, and Initialize an Empty List and Counters

#Import the requests library - 6.2.3
import requests

#Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=00e7cb7aed8565887497994e821448e0

# %%
#Import the datetime module from the dateime library
from datetime import datetime

#Create an empty list to hold the weather data.
city_data = []
#Print the beginning of the logging.
print("Beginning data Retrieval      ")
print("------------------------------")

#Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning data Retrieval
# ------------------------------

# %%
print(cities)
# Out:
# ['tual', 'busselton', 'port elizabeth', 'vestmannaeyjar', 'ushuaia', 'vao', 'upernavik', 'college', 'kerman', 'isangel', 'mataura', 'punta arenas', 'faanui', 'georgetown', 'lolua', 'bambous virieux', 'novikovo', 'cabo san lucas', 'concordia', 'kapaa', 'jiroft', 'hobart', 'ilulissat', 'belushya guba', 'pervomayskiy', 'sitka', 'port alfred', 'mar del plata', 'saldanha', 'mason city', 'cape town', 'tambo grande', 'dikson', 'mys shmidta', 'alanya', 'tocopilla', 'amderma', 'tyulyachi', 'yellowknife', 'te anau', 'illoqqortoormiut', 'carnarvon', 'cherskiy', 'bargal', 'thompson', 'ancud', 'new norfolk', 'pisco', 'khatanga', 'caluquembe', 'strezhevoy', 'huaraz', 'harlingen', 'nikolskoye', 'castro', 'cockburn town', 'nanortalik', 'usinsk', 'saint anthony', 'tiksi', 'butaritari', 'balad', 'albany', 'kununurra', 'bengkulu', 'camacha', 'nizhneyansk', 'saint-philippe', 'tasiilaq', 'torbay', 'puerto ayora', 'bluff', 'rikitea', 'bahia blanca', 'clyde river', 'tabialan', 'lompoc', 'tautira', 'malarti
# ...

# %%
# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    #We'll add a try-except block to our code to prevent the API request
# from stopping prematurely if the city_weather request isn't a valid 
# response. If the request isn't valid, the code will not find the first
# item requested, which is the dictionary "coord" with the code city_lat
# = city_weather["coord"]["lat"], and skip the city and continue to run.

# Run an API request for each of the cities.
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 31 of Set 13 | tual
# Processing Record 32 of Set 13 | busselton
# Processing Record 33 of Set 13 | port elizabeth
# Processing Record 34 of Set 13 | vestmannaeyjar
# Processing Record 35 of Set 13 | ushuaia
# Processing Record 36 of Set 13 | vao
# Processing Record 37 of Set 13 | upernavik
# Processing Record 38 of Set 13 | college
# Processing Record 39 of Set 13 | kerman
# Processing Record 40 of Set 13 | isangel
# Processing Record 41 of Set 13 | mataura
# Processing Record 42 of Set 13 | punta arenas
# Processing Record 43 of Set 13 | faanui
# Processing Record 44 of Set 13 | georgetown
# Processing Record 45 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 13 | bambous virieux
# Processing Record 47 of Set 13 | novikovo
# Processing Record 48 of Set 13 | cabo san lucas
# Processing Record 49 of Set 13 | concordia
# Processing Record 50 of Set 13 | kapaa
# Processing Record 51 of Set 13 | jiroft
# City not found. Skipping...
# ...

# %%
city_data_len = len(city_data)
city_data_len
# print ("The City data list is" city_data_len)
# Out:
# 585

# %%
# 6.2.7 -Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Miraflores  19.22  -98.81     71.01        32          40       13.87
# 1            Tual  -5.67  132.75     82.87        73           0        9.42
# 2       Busselton -33.65  115.33     78.01        30           0        6.02
# 3  Port Elizabeth -33.92   25.57     55.40        82           0       11.41
# 4  Vestmannaeyjar  63.44  -20.27     45.77        78         100       20.09
# 5         Ushuaia -54.80  -68.30     44.60        70          75       12.75
# 6             Vao -22.67  167.48     73.94        82          99       18.41
# 7       Upernavik  72.79  -56.15     22.91        97         100        5.03
# 8         College  64.86 -147.80     17.60        72          90        5.82
# 9          Kerman  30.28   57.08     35.60        29           0        4.70
#
#   Country                 Date
# 0      MX  2020-10-30 01:38:21
# 1      ID  2020-10-30 01:38:54
# ...

# %%
#Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed",""]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country                 Date    Lat     Lng  Max Temp  \
# 0        Miraflores      MX  2020-10-30 01:38:21  19.22  -98.81     71.01
# 1              Tual      ID  2020-10-30 01:38:54  -5.67  132.75     82.87
# 2         Busselton      AU  2020-10-30 01:34:22 -33.65  115.33     78.01
# 3    Port Elizabeth      ZA  2020-10-30 01:38:54 -33.92   25.57     55.40
# 4    Vestmannaeyjar      IS  2020-10-30 01:37:24  63.44  -20.27     45.77
# ..              ...     ...                  ...    ...     ...       ...
# 580       Steinbach      DE  2020-10-30 01:39:26  50.17    8.57     54.00
# 581         Tisovec      SK  2020-10-30 01:39:26  48.68   19.94     39.00
# 582            Emba      KZ  2020-10-30 01:35:20  48.83   58.14     38.84
# 583         Elverum      NO  2020-10-30 01:39:26  60.88   11.56     30.99
# 584      Miraflores      MX  2020-10-30 01:38:21  19.22  -98.81     71.01
#
#      Humidity  Cloudiness  Wind Speed
# 0          32          40       13.87
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# 6.3.1. - Import the time module. plot 1
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# 6.3.2. - Plot Latitude vs. Humidity
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
#6.3.3. - Plot Latitude vs. Cloudiness
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
#6.3.4 - Plot Latitude vs. Wind Speed
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# 6.4.2 - Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#o create a new DataFrame from a current DataFrame, 
#we can use the loc method on the current DataFrame. 
#The loc method accesses a group of rows and columns in the 
#current DataFrame by an index, labels, or a Boolean array. 
#The syntax to get a specific row from a current DataFrame 
#is row = df.loc[row_index].

index13 = city_data_df.loc[13]
index13
# Out:
# City                       Faanui
# Country                        PF
# Date          2020-10-30 01:37:13
# Lat                        -16.48
# Lng                       -151.75
# Max Temp                    80.22
# Humidity                       79
# Cloudiness                      0
# Wind Speed                   9.98
# Name: 13, dtype: object

# %%
#for latitudes greater than or equal to 0, we can filter the
#city_data_df DataFrame using the code 
#city_data_df["Lat"] >= 0. Executing this code will return 
#either "True" or "False" for all the rows that meet these 
#criteria.

city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 580     True
# 581     True
# 582     True
# 583     True
# 584     True
# Name: Lat, Length: 585, dtype: bool

# %%
#If we want to return a DataFrame with all data fitting the 
#criteria, for latitudes greater than or equal to 0, we can 
#use the loc method on the city_data_df DataFrame. Inside 
#the brackets, we would add the conditional filter 
#city_data_df["Lat"] >= 0 so that our statement would appear
#as:

city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0      Miraflores      MX  2020-10-30 01:38:21  19.22  -98.81     71.01
# 4  Vestmannaeyjar      IS  2020-10-30 01:37:24  63.44  -20.27     45.77
# 7       Upernavik      GL  2020-10-30 01:38:54  72.79  -56.15     22.91
# 8         College      US  2020-10-30 01:35:33  64.86 -147.80     17.60
# 9          Kerman      IR  2020-10-30 01:38:54  30.28   57.08     35.60
#
#    Humidity  Cloudiness  Wind Speed
# 0        32          40       13.87
# 4        78         100       20.09
# 7        97         100        5.03
# 8        72          90        5.82
# 9        29           0        4.70

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
#Northern Hemisphere - Lat and Max Temp
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \n for Maximum Temperature','Max Temp',(100,120))

# %%
#Southern Hemisphere - Lat and Max Temp
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for Maximum Temperature','Max Temp',(-50,90))

# %%
#6.4.3 - Northern Hemisphere - Lat and Humidity 
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
#Southern Hemisphere - Lat and Humidity
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
#6.4.4 - Northern Hemisphere - Lat and Cloudiness 
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(40,10))

# %%
#Southern Hemisphere - Lat and Cloudiness
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
#6.4.5 - Northern hemisphere - Lat and Wind Speed
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
